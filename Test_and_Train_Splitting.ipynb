# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import os
import pandas as pd
from os import walk
import math

# foldername = ['Aa', 'Ba', 'Bhaa', 'Ca', 'Cha']
filename = ['1.csv', '2.csv', '3.csv', '4.csv', '5.csv', '6.csv', '7.csv', '8.csv', '9.csv', '10.csv', '11.csv']
character_number = 0


for name in filename: 
  print("Character Number : ", character_number)
  filepath = "/content/drive/My Drive/8th_Sem_Internship/Printed/Aa/" + name

  with open(filepath, 'r+') as mycsv:
    length = 0

    reader = csv.reader(mycsv)
    for row in reader:
      if(len(row) == 0):
        continue
      else:
        length += 1

  with open(filepath, 'r+') as mycsv:
    i = 0
    reader = csv.reader(mycsv)
    
    for row in reader:

      if(len(row) == 0):
        continue

      elif(i < math.floor(0.8*length)):
        with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Aa/X_train.csv" , 'a') as train:                
          writer_train = csv.writer(train)
          writer_train.writerow(row)
          i += 1

        with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Aa/Y_train.csv" , 'a') as train:               
          writer_train = csv.writer(train)
          writer_train.writerow([character_number])
      
      else:
        with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Aa/X_test.csv" , 'a') as test:                
          writer_test = csv.writer(test)
          writer_test.writerow(row)
          i += 1
        
        with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Aa/Y_test.csv" , 'a') as test:               
          writer_train = csv.writer(test)
          writer_train.writerow([character_number])
    
  character_number += 1
# Out:
# Character Number :  0
# Character Number :  1
# Character Number :  2
# Character Number :  3
# Character Number :  4
# Character Number :  5
# Character Number :  6
# Character Number :  7
# Character Number :  8
# Character Number :  9
# Character Number :  10

# %%
import csv
import os
import pandas as pd
from os import walk
import math

foldername = ['Aa', 'Ba', 'Bhaa', 'Ca', 'Cha']
filename = ['1.csv', '2.csv', '3.csv', '4.csv', '5.csv', '6.csv', '7.csv', '8.csv', '9.csv', '10.csv', '11.csv']
character_number = 0


for folder in foldername:
  for name in filename: 
    print("Character Number : ", character_number)
    filepath = "/content/drive/My Drive/8th_Sem_Internship/Printed/CSV/" + folder + "/" + name

    with open(filepath, 'r+') as mycsv:
      length = 0

      reader = csv.reader(mycsv)
      for row in reader:
        if(len(row) == 0):
          continue
        else:
          length += 1

    with open(filepath, 'r+') as mycsv:
      i = 0
      reader = csv.reader(mycsv)
      
      for row in reader:

        if(len(row) == 0):
          continue

        elif(i < math.floor(0.8*length)):
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_train_0.csv" , 'a') as train:                
            writer_train = csv.writer(train)
            writer_train.writerow(row)
            i += 1

          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_train_0.csv" , 'a') as train:               
            writer_train = csv.writer(train)
            writer_train.writerow([character_number])
        
        else:
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_test_0.csv" , 'a') as test:                
            writer_test = csv.writer(test)
            writer_test.writerow(row)
            i += 1
          
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_test_0.csv" , 'a') as test:               
            writer_train = csv.writer(test)
            writer_train.writerow([character_number])
      
    character_number += 1
# Out:
# Character Number :  0
# Character Number :  1
# Character Number :  2
# Character Number :  3
# Character Number :  4
# Character Number :  5
# Character Number :  6
# Character Number :  7
# Character Number :  8
# Character Number :  9
# Character Number :  10
# Character Number :  11
# Character Number :  12
# Character Number :  13
# Character Number :  14
# Character Number :  15
# Character Number :  16
# Character Number :  17
# Character Number :  18
# Character Number :  19
# Character Number :  20
# Character Number :  21
# Character Number :  22
# Character Number :  23
# Character Number :  24
# Character Number :  25
# Character Number :  26
# Character Number :  27
# Character Number :  28
# Character Number :  29
# Character Number :  30
# Character Number :  31
# Character Number :  32
# Character Number :  33
# Character Number :  34
# Character Number :  35
# Character Number :  36
# Character Number :  37
# Character Number :  38
# Character Number :  39
# ...

# %% [markdown]
# ### VOWELS

# %%
import csv
import os
import pandas as pd
from os import walk
import math

folder_name = ['Aa', 'Ba', 'Bhaa', 'Ca', 'Cha', 'Da', 'Daa', 'Dha', 'Dhaa', 'Ga']
folder_name1 = ['Gha', 'Gna', 'Ha', 'Ja', 'Jha', 'Ka', 'Kha', 'Ksa', 'La', 'Laa'] 
folder_name2 = ['Ma', 'Na', 'Naa', 'Pa', 'Pha', 'Ra', 'Sa', 'Saa', 'Saaa', 'Ta'] 
folder_name3 = ['Taa', 'Tha', 'Thaa', 'Va', 'Ya']
filename = ['1.csv', '2.csv', '3.csv', '4.csv', '5.csv', '6.csv', '7.csv', '8.csv', '9.csv', '10.csv', '11.csv']
character_number = 0


for folder in folder_name:
  for name in filename: 
    print("Character Number : ", character_number)
    filepath = "/content/drive/My Drive/8th_Sem_Internship/Printed/CSV/" + folder + "/" + name

    with open(filepath, 'r+') as mycsv:
      length = 0

      reader = csv.reader(mycsv)
      for row in reader:
        if(len(row) == 0):
          continue
        else:
          length += 1

    with open(filepath, 'r+') as mycsv:
      i = 0
      reader = csv.reader(mycsv)
      
      for row in reader:

        if(len(row) == 0):
          continue

        elif(i < math.floor(0.8*length)):
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_train.csv" , 'a') as train:                
            writer_train = csv.writer(train)
            writer_train.writerow(row)
            i += 1

          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_train.csv" , 'a') as train:               
            writer_train = csv.writer(train)
            writer_train.writerow([character_number])
        
        else:
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_test.csv" , 'a') as test:                
            writer_test = csv.writer(test)
            writer_test.writerow(row)
            i += 1
          
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_test.csv" , 'a') as test:               
            writer_train = csv.writer(test)
            writer_train.writerow([character_number])
      
    character_number += 1
# Out:
# Character Number :  0
# Character Number :  1
# Character Number :  2
# Character Number :  3
# Character Number :  4
# Character Number :  5
# Character Number :  6
# Character Number :  7
# Character Number :  8
# Character Number :  9
# Character Number :  10
# Character Number :  11
# Character Number :  12
# Character Number :  13
# Character Number :  14
# Character Number :  15
# Character Number :  16
# Character Number :  17
# Character Number :  18
# Character Number :  19
# Character Number :  20
# Character Number :  21
# Character Number :  22
# Character Number :  23
# Character Number :  24
# Character Number :  25
# Character Number :  26
# Character Number :  27
# Character Number :  28
# Character Number :  29
# Character Number :  30
# Character Number :  31
# Character Number :  32
# Character Number :  33
# Character Number :  34
# Character Number :  35
# Character Number :  36
# Character Number :  37
# Character Number :  38
# Character Number :  39
# ...

# %%
for folder in folder_name1:
  for name in filename: 
    print("Character Number : ", character_number)
    filepath = "/content/drive/My Drive/8th_Sem_Internship/Printed/CSV/" + folder + "/" + name

    with open(filepath, 'r+') as mycsv:
      length = 0

      reader = csv.reader(mycsv)
      for row in reader:
        if(len(row) == 0):
          continue
        else:
          length += 1

    with open(filepath, 'r+') as mycsv:
      i = 0
      reader = csv.reader(mycsv)
      
      for row in reader:

        if(len(row) == 0):
          continue

        elif(i < math.floor(0.8*length)):
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_train.csv" , 'a') as train:                
            writer_train = csv.writer(train)
            writer_train.writerow(row)
            i += 1

          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_train.csv" , 'a') as train:               
            writer_train = csv.writer(train)
            writer_train.writerow([character_number])
        
        else:
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_test.csv" , 'a') as test:                
            writer_test = csv.writer(test)
            writer_test.writerow(row)
            i += 1
          
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_test.csv" , 'a') as test:               
            writer_train = csv.writer(test)
            writer_train.writerow([character_number])
      
    character_number += 1
# Out:
# Character Number :  110
# Character Number :  111
# Character Number :  112
# Character Number :  113
# Character Number :  114
# Character Number :  115
# Character Number :  116
# Character Number :  117
# Character Number :  118
# Character Number :  119
# Character Number :  120
# Character Number :  121
# Character Number :  122
# Character Number :  123
# Character Number :  124
# Character Number :  125
# Character Number :  126
# Character Number :  127
# Character Number :  128
# Character Number :  129
# Character Number :  130
# Character Number :  131
# Character Number :  132
# Character Number :  133
# Character Number :  134
# Character Number :  135
# Character Number :  136
# Character Number :  137
# Character Number :  138
# Character Number :  139
# Character Number :  140
# Character Number :  141
# Character Number :  142
# Character Number :  143
# Character Number :  144
# Character Number :  145
# Character Number :  146
# Character Number :  147
# ...

# %%
for folder in folder_name2:
  for name in filename: 
    print("Character Number : ", character_number)
    filepath = "/content/drive/My Drive/8th_Sem_Internship/Printed/CSV/" + folder + "/" + name

    with open(filepath, 'r+') as mycsv:
      length = 0

      reader = csv.reader(mycsv)
      for row in reader:
        if(len(row) == 0):
          continue
        else:
          length += 1

    with open(filepath, 'r+') as mycsv:
      i = 0
      reader = csv.reader(mycsv)
      
      for row in reader:

        if(len(row) == 0):
          continue

        elif(i < math.floor(0.8*length)):
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_train.csv" , 'a') as train:                
            writer_train = csv.writer(train)
            writer_train.writerow(row)
            i += 1

          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_train.csv" , 'a') as train:               
            writer_train = csv.writer(train)
            writer_train.writerow([character_number])
        
        else:
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_test.csv" , 'a') as test:                
            writer_test = csv.writer(test)
            writer_test.writerow(row)
            i += 1
          
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_test.csv" , 'a') as test:               
            writer_train = csv.writer(test)
            writer_train.writerow([character_number])
      
    character_number += 1
# Out:
# Character Number :  220
# Character Number :  221
# Character Number :  222
# Character Number :  223
# Character Number :  224
# Character Number :  225
# Character Number :  226
# Character Number :  227
# Character Number :  228
# Character Number :  229
# Character Number :  230
# Character Number :  231
# Character Number :  232
# Character Number :  233
# Character Number :  234
# Character Number :  235
# Character Number :  236
# Character Number :  237
# Character Number :  238
# Character Number :  239
# Character Number :  240
# Character Number :  241
# Character Number :  242
# Character Number :  243
# Character Number :  244
# Character Number :  245
# Character Number :  246
# Character Number :  247
# Character Number :  248
# Character Number :  249
# Character Number :  250
# Character Number :  251
# Character Number :  252
# Character Number :  253
# Character Number :  254
# Character Number :  255
# Character Number :  256
# Character Number :  257
# ...

# %%
for folder in folder_name3:
  for name in filename: 
    print("Character Number : ", character_number)
    filepath = "/content/drive/My Drive/8th_Sem_Internship/Printed/CSV/" + folder + "/" + name

    with open(filepath, 'r+') as mycsv:
      length = 0

      reader = csv.reader(mycsv)
      for row in reader:
        if(len(row) == 0):
          continue
        else:
          length += 1

    with open(filepath, 'r+') as mycsv:
      i = 0
      reader = csv.reader(mycsv)
      
      for row in reader:

        if(len(row) == 0):
          continue

        elif(i < math.floor(0.8*length)):
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_train.csv" , 'a') as train:                
            writer_train = csv.writer(train)
            writer_train.writerow(row)
            i += 1

          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_train.csv" , 'a') as train:               
            writer_train = csv.writer(train)
            writer_train.writerow([character_number])
        
        else:
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/X_test.csv" , 'a') as test:                
            writer_test = csv.writer(test)
            writer_test.writerow(row)
            i += 1
          
          with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Data_Split/Y_test.csv" , 'a') as test:               
            writer_train = csv.writer(test)
            writer_train.writerow([character_number])
      
    character_number += 1
# Out:
# Character Number :  330
# Character Number :  331
# Character Number :  332
# Character Number :  333
# Character Number :  334
# Character Number :  335
# Character Number :  336
# Character Number :  337
# Character Number :  338
# Character Number :  339
# Character Number :  340
# Character Number :  341
# Character Number :  342
# Character Number :  343
# Character Number :  344
# Character Number :  345
# Character Number :  346
# Character Number :  347
# Character Number :  348
# Character Number :  349
# Character Number :  350
# Character Number :  351
# Character Number :  352
# Character Number :  353
# Character Number :  354
# Character Number :  355
# Character Number :  356
# Character Number :  357
# Character Number :  358
# Character Number :  359
# Character Number :  360
# Character Number :  361
# Character Number :  362
# Character Number :  363
# Character Number :  364
# Character Number :  365
# Character Number :  366
# Character Number :  367
# ...

# %%
import csv
import os
import pandas as pd
from os import walk
import math

folder_name = ['Aa', 'Ba', 'Bhaa', 'Ca', 'Cha', 'Da', 'Daa', 'Dha', 'Dhaa', 'Ga', 'Gha', 'Gna', 'Ha', 'Ja', 'Jha', 'Ka', 'Kha', 'Ksa', 'La', 'Laa', 'Ma', 'Na', 'Naa', 'Pa', 'Pha', 'Ra', 'Sa', 'Saa', 'Saaa', 'Ta', 'Taa', 'Tha', 'Thaa', 'Va', 'Ya']
filename = ['1.csv', '2.csv', '3.csv', '4.csv', '5.csv', '6.csv', '7.csv', '8.csv', '9.csv', '10.csv', '11.csv']
character_number = 0

for name in filename: 
  print("Character Number : ", character_number)
  filepath = "/content/drive/My Drive/8th_Sem_Internship/Printed/Ka/" + name

  with open(filepath, 'r+') as mycsv:
    length = 0

    reader = csv.reader(mycsv)
    for row in reader:
      if(len(row) == 0):
        continue
      else:
        length += 1

  with open(filepath, 'r+') as mycsv:
    i = 0
    reader = csv.reader(mycsv)
    
    for row in reader:

      if(len(row) == 0):
        continue

      elif(i < math.floor(0.8*length)):
        with open("/content/drive/My Drive/8th_Sem_Internship/Printed/X_train.csv" , 'a') as train:                
          writer_train = csv.writer(train)
          writer_train.writerow(row)
          i += 1

        with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Y_train.csv" , 'a') as train:               
          writer_train = csv.writer(train)
          writer_train.writerow([character_number])
      
      else:
        with open("/content/drive/My Drive/8th_Sem_Internship/Printed/X_test.csv" , 'a') as test:                
          writer_test = csv.writer(test)
          writer_test.writerow(row)
          i += 1
        
        with open("/content/drive/My Drive/8th_Sem_Internship/Printed/Y_test.csv" , 'a') as test:               
          writer_train = csv.writer(test)
          writer_train.writerow([character_number])
    
  character_number += 1
